# %% [markdown]
# ## Course: Programming with data (INFOB2PWD)
#
# ### Students: Annette Holst, Georg Vasiliv, Robin Papenhuijzen and Rina van Woerden
#
# # Movie portal game
# We have developed a Movie Game! The story is about Indiana Jones who was running toward the Temple of Doom when a mysterious portal suddenly appeared, pulling him into another dimension. Now he is trapped and needs your help to return to the real world! To do so, you must complete four game worlds based on famous movies, where you can earn portal pieces along the way. Collect all four, and you can help Indiana Jones to escape back to the real world!
#
# The four game worlds are:
#
# * World 1: Inspired by Rapunzel: can you escape the tower and help Rapunzel find the floating latterns?
# * World 2: ?
# * World 3: ?
# * World 4: Inspired by Jumanji: find your path through the jungle, be careful since there is a thin line between risk and reward!
# Are you ready for the adventure?
#
# ### Source
# The fighting game in the first world was inspired by a github repository (source: https://github.com/orkslayergamedev/python-classes-text-battle/tree/master and https://www.youtube.com/watch?v=cM_ocyOrs_k). This code was implemented and edited to fit into the fighting scene.

# %%
# --------------- Imports ---------------
import random
from random import choice
from time import sleep
import os
from character import You, TwinBrother # import characters for fighting scene in first world from character file
from weapon import pan, sword, fists # import weapons for fighting scene in first world from weapon file

# --------------- Movieportal game ---------------
class movieportal_game():
    def __init__(self, name:str, points: int):
        # Game is not over
        self.game_over = False
        # Defining self.points
        self.points = points
        
        # User starts with no portal pieces (empty list)
        self.portalpieces = []
        # Describing portal piece of first world
        first_portal_piece = str("Portal piece of first world")
        # Defining self.first_portal_piece
        self.first_portal_piece = first_portal_piece
        # Describing portal piece of second world
        second_portal_piece = str("Portal piece of second world")
        # Defining self.second_portal_piece
        self.second_portal_piece = second_portal_piece
        # Describing portal piece of third world
        third_portal_piece = str("Portal piece of third world")
        # Defining self.third_portal_piece
        self.third_portal_piece = third_portal_piece
        # Describing portal piece of first world
        fourth_portal_piece = str("Portal piece of fourth world")
        # Defining self.fourth_portal_piece
        self.fourth_portal_piece = fourth_portal_piece
        
        # User starts with no items (empty inventory list)
        items = []
        # Defining self.items
        self.items = items
        # Description of item key
        key = str("A key")
        # Defining self.key
        self.key = key
        # Description of item satchel
        satchel = str("The stolen satchel of the queen")
        # Defining self.satchel
        self.satchel = satchel

        # Third world
        flamethrower = "Flamethrower"
        self.flamethrower = flamethrower
    
        # Welcoming player
        print("Indiana Jones: 'Welcome traveller, my name is Indiana Jones.'")
        # Ask the user for name, greet him/her and ask for help
        self.name = input("Indiana Jones: 'What is your name?'")
        
        # Users characteristics for fighting game in the first world (has to be after self.name is defined)
        you = You(name=self.name, health=100)
        # Charachteristics of twin brother for fighting game in the first world
        twinbrother = TwinBrother(name="Man with eyepatch", health=100, weapon=sword)
        
        # Dialogue pause
        sleep(1)
        # Dialogue
        print(f"Nice to meet you {self.name}!")
        print("Indiana Jones: 'The craziest thing has happened to me.'")
        print("Indiana Jones: 'I was running towards the temple of doom and all of a sudden a portal appeared in my pathway.'")
        # Dialogue pause
        sleep(1)
        # Dialogue
        print("Indiana Jones: 'I got sucked into this portal and now I'm stuck here...'")
        # Dialogue pause
        sleep(1)
        # Go to next scene
        self.helpout()
        
    # Function to create decision-point: (not) helping Indiana Jones
    def helpout(self):
        # List of answers
        answers = ["y", "n"]
        # Pre-define user input
        user_input = ""
        # Loop until the user gives a valid answer for the game to continue
        while user_input not in answers:
            # User types answer
            user_input = input("Indiana Jones: 'It seems like another dimension. Could you help me find my way back to the temple of doom?' (y/n)")
            # If answer is yes
            if user_input == "y":
                # Dialogue and dialogue pauses
                print("Thank you for wanting to help me. Let's start this adventure!")
                sleep(1)
                print("A bright blue portal swirls in front of you...")
                sleep(1)
                print("You step closer, feeling a strange pull.")
                # Calls the next scene
                self.portalscene()
            # If answer is no
            elif user_input == "n":
                # Dialogue
                print("I understand, it is a big job to ask of anyone. Maybe another time!")
                # Stops the game
                self.game_over = True
                # Restarts the game
                if __name__ == "__main__":
                    game = movieportal_game(name="Player", points=0)
                    game.start_game()
            # If input of the user isn't contained in the options, user should enter another option
            else:
                print("Please enter a valid answer.")

     # Function to choose a portal
    def portalscene(self):
        # Specifies variable that user needs all portal pieces of different world
        required_pieces = {self.first_portal_piece, self.second_portal_piece, self.third_portal_piece}
        # If user has achieved all portal pieces (aka all required portal pieces are contained in the set)
        if set(self.portalpieces) >= required_pieces:
            # Dialogue and dialogue pauses
            print("Hoorah, you've achieved all portal pieces! \nYou combine all portal pieces and a blue portal forms to the world of Indiana Jones.")
            sleep(2)
            # Refers to user name
            print(f"Indiana Jones: 'Thank you so much for helping me {self.name}! Now I can go back to my world.")
            sleep(2)
            print("Indiana Jones tips his hat and steps into the portal. The portal dissapears.")
            sleep(1)
            print("Congratulations! You've won the game.")
            # List of answers
            answers = ["y","n"]
            # Pre-define variable user input
            user_input = ""
            while user_input not in answers:
                # User types answer
                user_input = input("Do you want to play again? (y/n)")
                # If answer is yes
                if user_input == "y":
                    # Removes all elements (portal pieces) from list of achieved portal pieces
                    self.portalpieces.clear()
                    # Returns to the portal scene again (without any portal pieces) to escape the if loop
                    self.portalscene()
                # If answer is no
                elif user_input == "n":
                    # Dialogue
                    print("Thank you for playing this game. Till next time!")
                    # Stops the game
                    self.game_over = True
                # If input of the user isn't contained in the answers, user should enter another answer
                else:
                    print("Please enter a valid option for this game.")         
        # If not, user continues with choosing a world
        else:
            sleep(1)
            # Dialogue and dialogue pauses 
            print("\nYou feel light as air and open your eyes. There is no ground beneath you, yet you are standing. It seems like you are somewhere in space. The space is filled with all kinds of colours swirling around you. It is absolutely beautiful.")
            sleep(2)
            print("While you are taking the space in with eyes full of wonder, Indiana Jones clears his throat.")
            sleep(1)
            print("Indiana Jones: 'Since I've been here awhile already, I'll tell you what I know. \nAs you can see, there are four portals in front of us. \nEach portal belongs to a different movie dimension. \nTo get me back to the temple of doom we're going to have to build a portal to my world. \nAfter completing each portal adventure, we'll receive a piece of my dimensions portal. \nTo complete a world we'll need a certain amount of points. \nIn order to get me back to my world we'll need all portal pieces. I haven't succeeded to complete any portal adventures, but I guess you already figured that out, since I'm still here.'")
            sleep(4)
            print("Indiana Jones: 'There are four portals. Starting from the left, which one of the portals do you want to go into?'")
            # List of options
            portals = ["first", "second", "third", "fourth"]
            # Pre-define variable user input
            user_input = ""
            # Loop until the user gives a valid answer for the game to continue
            while user_input not in portals:
                # Specify user input: user can choose a portal
                user_input = input("Choose a portal: first/second/third/fourth")
                # If user selects first world, then call the first function of that world
                if user_input == "first":
                    print("Here we go!")
                    self.first_world()
                # If user selects second world, then call the first function of that world
                elif user_input == "second":
                    print("OK, let's go!")
                    self.second_world()
                # If user selects third world, then call the first function of that world
                elif user_input == "third":
                    print("Let's hope for the best!")
                    self.third_world()
                # If user selects fourth world, then call the first function of that world
                elif user_input == "fourth":
                    print("Let's go!")
                    self.fourth_world()
                # If input of the user isn't contained in the options, user should enter another option
                else:
                    print("Please enter a valid option for this game.")

    # --------------- First world: Rapunzel ---------------
        
    # Beginning scene of Rapunzels world
    def first_world(self):
        # If the user has already achieved the first portal piece
        if self.first_portal_piece in self.portalpieces:
            # Pre-define user variable
            user_input = ""
            # List of answers
            answers = ["y", "n"]
            # Loop until the user enters one of the given options
            while user_input not in answers:
                # User types answer
                user_input = input("You've already completed this world. If you start again, you'll need to earn this portal piece again. Do you want to continue? (y/n)")
                # If answer is yes
                if user_input == "y":
                    # Remove the first portal piece from the list of portal pieces
                    self.portalpieces.remove(self.first_portal_piece)
                # If answer is no
                elif user_input == "n":
                    # User goes back to portal scene
                    self.portalscene()
                # If input of the user isn't contained in the options, user should enter another answer
                else:
                    print("Please enter a valid option.")
        # Start world with zero points for the user
        self.points = 0
        # Dialogue and dialogue pauses
        print(f"Welcome {self.name}, in order to win a portal piece and complete this world, you'll need to earn 100 points. Good luck!")
        sleep(2)
        print("\nYou find yourself in a small and round room. The walls are made out of stone and covered with beautiful paintings.")
        sleep(1)
        print("There's a narrow window high above you. There is a girl there brushing her extremely long and golden hair. \nHer back is turned towards you.")
        sleep(1)
        # List of options
        options = ["1","2", "3"]
        # Pre-define variable user input
        user_input = ""
        # Loop until the user enters one of the given options
        while user_input not in options:
            print("1. Say hello \n2. Walk towards the paintings and take a better look at it \n3. You reach for the pan in front of you")
            # User types option
            user_input = input("Choose an action (1, 2, or 3): ")
            # If user selects option 1
            if user_input == "1":
                # Dialogue and dialogue pauses
                print("The girl lets out a shriek and grabs the pan next to her.")
                sleep(1)
                print("\nRapunzel: 'Who are you guys and how did you get into my house?', she says.")
                sleep(1)
                # Referring to the username given by the user
                print(f"\nIndiana Jones:  'My name is Indiana Jones. It seems like my friend {self.name} and I have landed in your world.'")
                sleep(1)
                print(f"Indiana Jones: '{self.name} is helping me to return to my own world. What is your name?'")
                sleep(1)
                print("\nRapunzel: 'My name is Rapunzel.'")
                sleep(1)
                print("\nIndiana Jones: 'Well, nice to meet you Rapunzel. Could you maybe get us out of here?'")
                # Calls the next scene 
                self.escaping_tower()
            # If user selects option 2
            elif user_input == "2":
                # Dialogue and dialogue pauses
                print("The wooden floor creaks as you begin to move.")
                sleep(1)
                print("The girl turns towards the noise. She grabs the pan behind her. \nRapunzel: 'Who are you guys and how did you get in here?'")
                sleep(1)
                # Referring to the username given by the user
                print(f"\nIndiana Jones: 'Sorry, we didn't mean to scare you. I'm Indiana Jones and this is {self.name}.'")
                sleep(1)
                print("\nIndiana Jones: 'It seems like we have landed in your world.'")
                sleep(1)
                print(f"Indiana Jones: '{self.name} is helping me to return to my own world. What is your name?'")
                sleep(1)
                print("\nRapunzel: 'My name is Rapunzel.'")
                sleep(1)
                print("\nIndiana Jones: 'Well, nice to meet you Rapunzel. Could you maybe get us out of here?'")
                # Calls the next scene 
                self.escaping_tower()
            # If user selects option 3
            elif user_input == "3":
                # Dialogue and dialogue pauses
                print("You stumble over a loose wooden tile. She turns towards the noise. \nRapunzel: 'Who are you guys and what are you doing in my home?'")
                sleep(1)
                # Referring to the username given by the user
                print(f"\n{self.name}:  'My name is {self.name}. It seems like Indiana Jones and I have landed in your world.'")
                sleep(1)
                print(f"Indiana Jones: 'Yes, {self.name} is helping me to return to my own world. What is your name?'")
                sleep(1)
                print("\nRapunzel: 'My name is Rapunzel.'")
                sleep(1)
                print("\nIndiana Jones: 'Well, nice to meet you Rapunzel. Could you maybe get us out of here?'")
                # Calls the next scene 
                self.escaping_tower()
            # If input of the user isn't contained in the options, user should enter another option
            else:
                print("Please enter a valid option for this game.")

    # Escaping tower scene
    def escaping_tower(self):
        # Dialogue and dialogue pauses
        sleep(2)
        print("\nRapunzel: 'Frankly, I've never left this tower... I'm not sure if I can help you guys get out, but maybe together we can figure it out.'")
        sleep(1)
        print("\nYou look around the room. There are a few things that stand out: \n1. A narrow window high up \n2. A golden chest \n3. Rapunzels long hair")
        # List of options
        options = ["1", "2", "3"]
        # Pre-define variable user input
        user_input = ""
        # Loop until the user enters one of the given options
        while user_input not in options:
            # Dialogue and dialogue pauses
            sleep(2)
            print("\nWhat do you want to do?")
            print("1. Try climbing out of the window \n2. Open the golden chest \n3. Ask if Rapunzel could make a rope out of her hair")
            # User types option
            user_input = input("Choose an option (1, 2 or 3): ")
            # If user selects option 1
            if user_input == "1":
                # Calls the falling scene
                self.falling()
            # If user selects option 2
            elif user_input == "2":
                sleep(1)
                print("The golden chest is locked. You'll need to find the key first.")
                sleep(1)
                print("Rapunzel: 'Mother says I'm not allowed to open the chest.'")
                # Calls the key finding scene
                self.keyfinding()
            # If user selects option 3
            elif user_input == "3":
                self.option3_escaping_tower()
            # If input of the user isn't contained in the options, user should enter another option
            else:
                print("Please enter a valid option for this game.")
    
    # To avoid repetition of code this function is created to cover an option of escaping the tower
    def option3_escaping_tower(self):
        # Dialogue and dialogue pauses
        sleep(1)
        print("Of course! You know, I've always wanted to see the floating latterns at the castle. Could I maybe come along with you guys?")
        sleep(1)
        print("Indiana Jones: 'Of course you can come with us!'")
        sleep(1)
        print("As you step towards the edge of the tower, Rapunzel gathers her long, golden hair, securing it around a sturdy stone pillar. She tosses her just braided hair over the side.")
        sleep(1)
        print("You grab her braid and look down. It is definitely a pretty high tower. The wind whips your face. You are scared.")
        sleep(1)
        # List of possible answers
        answers = ["y", "n"]
        # Pre-define answer user will put in
        answer = ""
        # Loop until the user enters one of the given answers
        while answer not in answers:
            # User types answer
            answer = input("Rapunzel: 'Do you want us to count down before you jump?' (y/n)")
            # If answer is yes
            if answer == "y":
                # Dialogue and dialogue pauses
                sleep(1)
                print("You nod your head.")
                sleep(1)
                print("Rapunzel: 'OK, I'll count to three.'")
                sleep(1)
                # For-loop to count from 1 to 3
                for i in range(1, 4):
                    print(i)
                    # Dialogue and referring to user name
                    print(f"{self.name}: Here I go!")
                    # Calls the next scene
                    self.outsidetower_scene()
            # If answer is no
            elif answer == "n":
                # Dialogue and dialogue pause
                sleep(1)
                print("You hold your breath and jump, while holding onto the braided hair.")
                # Calls the next scene
                self.outsidetower_scene()
            # If input of the user isn't contained in the answer, user should enter another answer
            else:
                print("Please enter a valid option for this game.")

    # Falling scene
    def falling(self):
        # Dialogue and dialogue pauses
        sleep(2)
        print("You climb the wall to reach the window.")
        # Long dramatic pause
        sleep(3)
        print("Oh no, your foot slips of the steep wall. You fall. You lose 25 points.")
        sleep(1)
        # User loses 25 points 
        self.points = self.points - 25
        # Tells user how much points he has at the moment
        print(f"You've got {self.points} points.")
        sleep(1)
        print("You still want to escape. What will you do next?")
        # List of options
        options = ["1", "2"]
        # Pre-define variable user input
        user_input = ""
        # Loop until the user enters one of the given options
        while user_input not in options:
            # Dialogue and dialogue pauses
            sleep(2)
            print("\nWhat do you want to do?")
            sleep(1)
            print("1. Open the golden chest \n2. Ask if Rapunzel could make a rope out of her hair")
            # User types option
            user_input = input("Choose an option (1 or 2): ")
            sleep(1)
            # If user selects option 1
            if user_input == "1":
                # If key is already in the items list
                if self.key in self.items:
                    # Skips key finding scene and calls unlocking chest scene
                    self.unlockchest()
                # If user hasn't found the key yet
                else:
                    # Dialogue and dialogue pauses
                    sleep(1)
                    print("The golden chest is locked. You'll need to find the key first.")
                    sleep(1)
                    print("Rapunzel: 'Mother says I'm not allowed to open the chest.'")
                    # Calls the key finding scene
                    self.keyfinding()
            # If user selects option 2
            elif user_input == "2":
                # To avoid repetition, refers to escaping tower option
                self.option3_escaping_tower()
            # If input of the user isn't contained in the options, user should enter another option
            else:
                print("Please enter a valid option for this game.")

    # Finding the key scene
    def keyfinding(self):
        # Dialogue and dialogue pauses
        sleep(2)
        print("\nYou look around. Where will this key be?")
        sleep(1)
        # Prints three possible options
        print("\n1. In the drawer of the kitchen cabinet \n2. Underneath the loose wooden tile \n3. Underneath the plant pot")
        sleep(1)
        # Option where the key is hidden
        options = ["1"]
        # Pre-define variable user input
        user_input = ""
        # loop until the user enters the right option
        while user_input not in options:
            # User types option
            user_input = input("Where do you think the key will be? (1, 2 or 3)")
            # If input is option 1
            if user_input == "1":
                # Dialogue
                print("You've found the key. You unlock the chest with the key.")
                # Add key to item list
                self.items.append(self.key)
                # Calls the next scene
                self.unlockchest()
            # Prompts user to try a different option
            else:
                print("The key is not there. Please try again.")

    # Unlocking the chest scene
    def unlockchest(self):
        # If satchel is already in the items list
        if self.satchel in self.items:
            # Dialogue
            print("Looks like someone has already taken the stolen satchel and put it in his bag.")
        # If satchel is not in items list
        else:
            # Dialogue and dialogue pauses
            sleep(2)
            print("\nYou find the stolen satchel of the queen.")
            # List of answers
            answers = ["y", "n"]
            # Pre-define variable user input
            answer = ""
            # Loop until the user enters one of the given answers
            while answer not in answers:
                # User types answer
                answer = input("Do you want to put the satchel in your bag? (y/n)")
                # If answer is yes
                if answer == "y":
                    # Add satchel to items list
                    self.items.append(self.satchel)
                    print("You've succesfully put the satchel in your bag.")
                # If answer is no
                elif answer == "n":
                    print("Indiana Jones: 'Well, I guesss the Queen won't miss it.'")
                # If input of the user isn't contained in the options, user should enter another answer
                else:
                    print("Please enter a valid option.")
        # Dialogue and dialogue pause
        sleep(1)
        print("\nRapunzel: 'You guys really have to go before mother comes.'")
        # List of options
        options = ["1", "2"]
        # Pre-define variable user input
        user_input = ""
        # Loop until the user enters one of the given options
        while user_input not in options:
            print("1. Try climbing out of the window \n2. Ask if Rapunzel could make a rope out of her hair")
            # User enters option
            user_input = input("What do you want to do?")
            # If input is option 1
            if user_input == "1":
                # Calls falling scene
                self.falling()
            # If input is option 2
            elif user_input == "2":
                # Dialogue and dialogue pause
                sleep(1)
                print("Of course! You know, I've always wanted to see the floating latterns at the castle. Could I maybe come along with you guys?")
                print("Indiana Jones: 'Of course you can come with us!'")
                # Calls outside the tower scene
                self.outsidetower_scene()
            # If input of the user isn't contained in the options, user should enter another answer
            else:
                print("Please enter a valid option for this game.")

    # Scene outside the tower
    def outsidetower_scene(self):
        # Dialogue pause
        sleep(2)
        # User gains 25 points
        self.points = self.points + 25
        # Tells how much points user currently has
        print(f"\nYou've helped Rapunzel escaped the tower. You gain 25 points. You've got {self.points} points.")
        # Dialogue and dialogue pauses
        sleep(1)
        print("Help Rapunzel get to the castle to see the floating lights.")
        sleep(1)
        print("\nThe are surrounded by trees. Looking west, you see the castle rising above the trees.")
        sleep(1)
        print("You see a beautiful white horse that seems to be stuck in a bush.")
        sleep(1)
        print("There's not a lot of time before the mother of Rapunzel returns, what do you do?")
        print("\n1. There's no time, you start walking towards the castle \n2. You free the horse")
        sleep(1)
        # List of options
        options = ["1", "2"]
        # Pre-define variable user input
        user_input = ""
        # Loop until the user enters one of the given options
        while user_input not in options:
            # User enters option
            user_input = input("What would you like to do? (1 or 2)")
            # If input is option 1
            if user_input == "1":
                # Dialogue
                print("The three of you start heading west straight through the forest.")
            # If input is option 2
            elif user_input == "2":
                # Dialogue and dialogue pause
                print("The horse thanks you by licking your face.")
                sleep(1)
                # User gains 10 points
                self.points = self.points + 10
                # Tells how much points user currently has 
                print(f"You gain 10 points for doing a good deed. You've got {self.points} points.")
                print("The horse happily drafts away. You continue heading west.")
            # If input of the user isn't contained in the options, user should enter another answer
            else:
                print("Please enter a valid option for this game.")
        # Dialogue and dialogue pauses
        sleep(1)
        print("While heading your way towards the castle, you hear leaves cracking behind you.")
        sleep(1)
        print("You turn towards the noise and see an old, mean looking lady hiding half behind the trees. \nBehind her there are two enormous fully-inked men. \nThey look like twins. One of the men is wearing an eyepatch. \nShe's looking at Rapunzel.")
        sleep(2)
        print("Mother Gothel: 'Rapunzel, what did I tell you about talking to strangers? What are you doing with these people?'")
        sleep(1)
        print("Rapunzel: 'I went with them to see the floating latterns, mother.'")
        sleep(1)
        print("Mother Gothel: 'Don't be silly Rapunzel, come with me and we'll go home.'")
        sleep(1)
        print("Rapunzel: 'Well, I don't want to come with you.'")
        sleep(1)
        print("Mother Gothel tugs on Rapunzel her arm. \nMother Gothel: 'You need to come with me child.'")
        sleep(1)
        print("Rapunzel: 'Let go of me.'")
        sleep(1)
        print("Indiana Jones: 'You heard the lady. Let her go.'")
        sleep(1)
        print("Mother Gothel: 'I am not letting her go without a fight.'")
        sleep(1)
        print("The men who were once behind her are now standing infront of you.")
        sleep(1)
        print("Indiana Jones looks towards you and winks. \nIndiana Jones: 'Well, then a fight you shall have.'")
        sleep(1)
        print("Indiana Jones: 'You take one and I take the other.'")
        sleep(1)
        print("The man that's approaching you has a sword.")
        sleep(1)
        print("You look around.")
        sleep(2)
        print("Rapunzel has a pan attached to her dress. There is also a sword lying on the ground.")
        sleep(1)
        # Calls choosing weapon function
        self.choose_weapon()

    def choose_weapon(self):
        # Makes sure that health of user is 100 (full health) before each fight
        you.health = 100
        # Health of enemy is 100 (full health)
        twinbrother.health = 100
        # List of options
        options = ["fists", "pan", "sword"]
        # Pre-define variable user input
        user_input = ""
        # Loop until the user enters one of the given options
        while user_input not in options:
            # User enters option
            user_input = input("Choose your own weapon: fists/pan/sword")
            # If input is fists
            if user_input == "fists":
                # Calls equip function to equip user with fists as weapon
                you.equip(fists)
                # Calls fighting game
                self.attack()
            # If input is pan
            elif user_input == "pan":
                # Calls equip function within character file to equip users' input weapon
                you.equip(pan)
                # Calls fighting game
                self.attack()
            # If input is sword
            elif user_input == "sword":
                # Calls equip function within character file to equip users' input weapon
                you.equip(sword)
                # Calls fighting game 
                self.attack()
            # If input of the user isn't contained in the options, user should enter another answer
            else: 
                print("Please enter a valid option.")

    # Fighting scene
    def attack(self):
        # Clears the terminal screen
        os.system("cls")
        # Dialogue pause
        sleep(2)
        # Starts an infinite loop for the fight until user loses/wins
        while True:
            # User presses Enter
            enter = input("Press Enter to attack")
            # If user presses enter
            if enter == "":
                # User attack twin brother
                you.attack(twinbrother)
                # Twin brother attacks user
                twinbrother.attack(you)
                # Draw users health bar
                you.health_bar.draw()
                # Draw twin brothers' health bar
                twinbrother.health_bar.draw()
                
                # If user loses (meaning users' health = 0)
                if you.health == 0:
                    # Dialogue and dialogue pause
                    sleep(2)
                    print("Sadly, you lost the fight. Please try again with a different weapon.")
                    # Rematch, possibily choosing another weapon
                    self.choose_weapon()
                # If users'health is not zero
                else:
                    # If user wins (meaning twin brothers' health = 0)
                    if twinbrother.health == 0:
                        # User gains 25 points
                        self.points = self.points + 25
                        # Dialogue and dialogue pauses
                        sleep(2)
                        # Tells user how much points he/she has currently got
                        print(f"Hoora, you've beated the men with the eye patch. \nYou gain 25 points. You've got {self.points} points.")
                        sleep(1)
                        print("You look to your right and see that Indiana Jones has beaten the other twin brother.")
                        sleep(1)
                        print(f"Rapunzel grabs your hand. \nRapunzel: 'We have to go now {self.name}!'")
                        sleep(1)
                        print("You run towards the village.")
                        # Calls the next scene
                        self.village()
                    # Continue pressing enter
                    else:
                        print("Press Enter to attack")
            # If input of the user isn't Enter, user should enter Enter
            else: 
                print("Please press Enter to attack.")

    # Village scene
    def village(self):
        # Dialogue and dialogue pauses
        sleep(3)
        print("You enter the lively village, where music fills the air and people dance joyfully. \nLanterns sway above as vendors sell fresh pastries and flowers. \nChildren laugh, weaving through the crowd. \nThe castle stands tall in the distance.")
        sleep(1)
        print("While you look around, a kid hops towards you and gives you a flower.")
        sleep(1)
        print("What do you do? \n1. Dance with the villagers \n2. Go to the castle \n3. Introduce yourself to the kid and tell a joke")
        sleep(1)
        # List of options
        options = ["1", "2", "3"]
        # Pre-define variable user input
        user_input = ""
        # Loop until the user enters one of the given options
        while user_input not in options:
            # User enters option
            user_input = input("Choose an option (1, 2 or 3): ")
            sleep(1)
            # If input is option 1
            if user_input == "1":
                # User gains 10 pints
                self.points = self.points + 10
                # Dialogue and dialogue pauses
                print(f"Way to go! An adventure isn't an adventure without a little fun. \nDue to the happiness of your travelcompanions gain 10 points. You've got {self.points} points.")
                sleep(3)
                print("After dancing you make your way towards the castle.")
                # Calls the castle function
                self.castle()
            # If input is option 2
            elif user_input == "2":
                # Dialogue
                print("You make your way towards the castle.")
                # Calls the castle function
                self.castle()
            # If input is option 3
            elif user_input == "3":
                # Calls the joke telling function
                self.joke_telling()
            # If input of the user isn't contained in the options, user should enter another answer
            else:
                print("Please enter a valid option for this game.")

    # Function to tell a joke
    def joke_telling(self):
        #Two possible joke questions and corresponding answers separated by commas 
        jokes = (
            (f"\n{self.name}:'What’s powerful enough to clear any obstacle from Rapunzel’s path?'", f"n{self.name}: 'A hair-icane!'"),
            (f"\n{self.name}:'Why did Rapunzel never experience fun?'", f"{self.name}: 'She never let her hair down.'")
        )
        # Two possible reactions of the kid, result of the reaction and change in points of user according to the reaction of the kid
        reaction_kid = (
            ("\nThe kid likes the joke and starts to laugh.", f"You gain ten points. You've got {self.points} points.", self.points + 10),
            ("\nThe joke wasn't that funny. The kid doesn't laugh.", f"You lose ten points. You've got {self.points} points.", self.points - 10)
        )
        # Tell a random joke
        joke, answer = choice(jokes)
        # First print the joke
        print(joke)
        # Wait for answer
        sleep(2)
        # Then print the answer of the joke
        print(answer)
        # Wait for reaction
        sleep(2)
        # Kids reaction (random)
        reaction, result, change_points = random.choice(reaction_kid)
        # Print the reaction of the kid
        print(reaction)
        # Adjust users points according to the reaction
        self.points += change_points 
        # Print the result of the reaction of the kid
        print(result)
        # Dialogue and dialogue pause
        print("You wave the kid goodbye and make your way towards the castle.")
        sleep(1)
        # Calls the next scene
        self.castle()

    # Castle scene
    def castle(self):
        # Dialogue and dialogue pauses
        print("You passed the guards and the grand door creaks open. \nThe door opens to a grand hall surrounded with beautiful paintings.")
        sleep(1)
        print("At the end of the hall the queen and king sit on the throne.")
        # If satchel is contained in list of items
        if self.satchel in self.items:
            # Dialogue and dialogue pauses
            print("Indiana Jones: 'Your majesty, we've brought you your stolen satchel.'")
            sleep(1)
            print("You get the satchel out of your bag and bring it towards them.")
            sleep(1)
            # Tells how much points user gained and currently has
            print(f"Hoora, you've returned the satchel to the queen. You gain 25 points. You've got {self.points} points.")
        # If satchel isn't contained in list of items
        else:
            print("Queen: 'Come in, what is it you want?'")
        # Dialogue and dialogue pauses
        sleep(1)
        print("The queens' gaze locks on Rapunzel. \nSlowly, she stands, her hand covering her mouth, eyes glistening.")
        sleep(1)
        print("Queen: '...Rapunzel?'")
        sleep(1)
        print("Rapunzel stiffens and looks confused.")
        sleep(1)
        print("Queen: it's you... my daughter. You were stolen many years ago by a witch.")
        sleep(1)
        print("Rapunzel's breath catches. \nEmotion overwhelms her as she collapses into the Queen's embrace.")
        sleep(1)
        print("Indiana Jones glances at you, raising an eyebrow.")
        sleep(1)
        print("Guess the stolen satchel wasn't the real treasure after all.")
        # User gains 40 points
        self.points = self.points + 40
        # Tells how much points user gained and currently has
        print(f"Hoorah, you've returned the long lost daughter of the queen. \nYou gain 40 points. \nYou've got {self.points} points.")
        sleep(1)
        # If user has less than 100 points achieved in this world
        if self.points < 100:
            # Dialogue
            print("For you this adventure has not come to an end, since you have not reached 100 points. \nIn order for you to complete this world and gain a portal piece, you'll need 100 points.")
            # List of answers
            answers = ["leave","retry"]
            # Pre-define variable answer
            answer = ""
            # Loop until the user enters one of the given answers
            while answer not in answers:
                # User types answer
                answer = input("Do you want to leave this world without getting a portal piece or try again? (leave/retry)")
                # If input is leave
                if answer == "leave":
                    print("You've not gained a portal piece and will be transported back to the portal room.")
                    # Go back to portal choosing scene
                    self.portalscene()
                # If input is retry
                elif answer == "retry":
                    sleep(2)
                    print("You'll transport to the beginning of this adventure to try again. \nPick a different path to earn more points.")
                    self.first_world()
                # If input of the user isn't contained in the options, user should enter another answer
                else:
                    print("Please enter a valid option.")
        # If user has gained 100 points or more in this world
        else:
            # User gains the portal piece of first world
            self.portalpieces.append(self.first_portal_piece)
            # Tells which portal pieces user currently has
            print(f"Hoorah, you've completed this world and achieved a portal piece! \nYou've got the following portal pieces: {self.portalpieces}.")
            # Calls the portal scene
            self.portalscene()

    
    # --------------- Second world: Matrix ---------------
    
    #Main menu for choosing the world or exiting the game
    def choose_world(self):
        while True: #Infinite loop until player exits
            print("\nWhich simulation do you want to enter?")
            print("1. The Matrix World")
            print("2. Exit simulation")
            choice = input("Enter your choice (1/2): ") #Gets the user input
            
            if choice == "1": #If user chooses to enter The Matrix world (second world)
                self.second_world()
            elif choice == "2":
                print("Thanks for playing! Goodbye.")
                break #Will exit the loop
            else:
                print("Invalid choice, please try again.") #Will handle invalid input
    
    #Main function for the second world
    def second_world(self):
        #Checks if player has already earned the portal piece
        if self.second_portal_piece in self.portalpieces:
            user_input = input("You've already completed this world. If you start again, you will have to earn this portal piece again. Do you want to continue? (y/n): ")
            if user_input.lower() == "n":
                return
            elif user_input.lower() == "y":
                self.portalpieces.remove(self.second_portal_piece) #Remove the portal piece if the player would like to play again
        
        print("\nIndiana Jones wakes up in a dark city alley, neon lights flickering above. A mysterious figure in a trench coat approaches him.")
        sleep(2)
        print("'Welcome to The Matrix. You need to make a choice if you want to survive.'")
        sleep(3) #Break for three seconds so the game is more clear
       
        self.choose_door()
        
        #Check if enough points are collected in order for the player (indiana jones) to get the portal piece
        if self.points >= 100:
            print("\nCongratulations! Indiana Jones has collected enough points and earned another portal piece to get closer to going home")
            self.portalpieces.append(self.second_portal_piece) #Add element to portal pieces list
        else:
            print("\nYou haven't collected enough points yet. Try again!")
            self.second_world()

    #Function to choose an action by selecting a coloured door
    def choose_door(self):
        while True:
            print("\nIn front of you are four doors:") #choosing door to go to different interactions/games within my world
            print("1. A Blue Door") 
            print("2. A Yellow Door")
            print("3. A Green Door")
            choice = input("Which door do you enter? (1/2/3): ")
            
            if choice == "1":
                self.subway_shootout() #Is connected to the blue door
            elif choice == "2":
                self.virtual_reality_maze() #Is connected to the yellow door 
            elif choice == "3": 
                self.code_hacking_game() #Is connected to the green door
            else:
                print("Invalid choice, please select a valid door.")
    
    #Subway shootout game
    def subway_shootout(self):
        print("\nIndiana Jones enters a subway station. Suddenly, an agent appears, and the only way out is through him!")
        sleep(1)
        bullets = 5  # Starting bullets
        enemy_health = 2  #The lifes of the agent
        while bullets > 0 and enemy_health > 0:
            action = input("Do you shoot (s), dodge (d), or find cover (c)? ")
            if action.lower() == "s" and random.choices([True, False], weights=[70, 30])[0]: #Randomness to the game but it is more likely to earn points, because 70/30 chance (not 50/50)
                print("You fire a shot! The agent dodges but gets grazed!")
                enemy_health -= 1 #Decrease of one life point
                self.points += 10 #Adding 10 points when the shot was a hit
                bullets -= 1 #Decrease of one bullet when the player shot one
            elif action.lower() == "d" and random.choices([True, False], weights=[70, 30])[0]:
                print("Indiana dodges the agent's bullet, moving in bullet-time!")
            elif action.lower() == "c" and random.choices([True, False], weights=[70, 30])[0]:
                print("You take cover and reload your gun!")
                bullets = 5 #Still five bullets cause the player did not loose any
            else:
                print("The agent fires back! You take a hit!")
                bullets -= 1
        if enemy_health <= 0:
            print("You take down the agent and escape! Extra points awarded!")
            self.points += 30
        else:
            print("You ran out of ammo! The agent eliminates you! Try again.")
            self.subway_shootout()

    # Virtual reality maze challenge
    def virtual_reality_maze(self):
        print("\nIndiana Jones finds himself inside a virtual reality maze, a glitching construct of The Matrix.")
        sleep(2)
        print("The walls shift and change as he moves. He must find the right path before the system resets!")
        sleep(1)
        
        for i in range(3):  #Adds multiple decision points so that I will not have to retype the code three times
            print(f"\nStage {i + 1} of the maze") #By using i + 1, the displayed phase numbers become Stage 1, Stage 2, and Stage 3, making it clearer for the player otherwise the player will begin at Stage 0
            correct_path = random.choice(["left", "right", "forward"])
            while True:
                choice = input("Do you go left, right, or forward? ").lower()
                if choice == correct_path:
                    print("The walls solidify, and you proceed to the next phase of the maze!")
                    self.points += 10  #Award points per phase
                    break
                else:
                    print("The walls shift, and you're sent back to the start of this phase! Try again.")
        
        print("You successfully navigate the maze and escape the simulation glitch!")
        self.points += 50  # Final reward for completion
        sleep(2)
            
    # Code for hacking game with multiple challenges and a interaction with a Matrix character
    def code_hacking_game(self):
        print("\nAs you approach the console, a dark figure appears from the shadows.")
        sleep(2)
        print("It's Trinity. She nods at you and says, 'You need to act fast, the Agents are tracking us.'")
        sleep(2)
        print("'The system is heavily encrypted. You'll need to bypass multiple security layers.'")
        sleep(2)
        print("She hands you a small device. 'Use this decryption key wisely, but you'll still need to prove yourself.'")
        sleep(2)
        print("'Would you want to help me out to hack the system and earn points for your portal piece so that we can both be safe?'")
        sleep(1)
        response = input("Will you help? (y/n): ").lower()
        if response == 'n':
            print("Trinity shakes her head. 'Then we’re all doomed.' The simulation resets.")
            sleep(2)
            go_back = input("Do you want to go back to the main menu? (y/n): ").lower()
            if go_back == 'y':
                self.choose_world()
                return
            else:
                print("Trinity sighs. 'Alright, let's try another way.'")
                self.subway_shoutout()
                return
        elif response == 'y':
            print("Trinity nods. 'Alright, let's do this.'")
        sleep(3)

        print("You sit before a console. The Matrix code scrolls rapidly.")
        sleep(2)
        print("To hack the system, you must complete multiple challenges.")
        sleep(2)
        
         #First challenge: Disable the Security System
        print("Challenge 1: Disable the Security System")
        print("Before hacking the system, you must bypass a security firewall by cutting the right wire.")
        print("You see three wires: Red, Blue, and Green.")
        correct_wire = random.choice(["Red", "Blue", "Green"]) 
        
        while True:
            user_wire = input("Which wire do you cut? (Red/Blue/Green) (Type 'hint' for help): ").capitalize()
            if user_wire.lower() == "hint":
                if correct_wire == "Red":
                    print("Hint: The correct wire is the color of danger but also sometimes luck.")
                elif correct_wire == "Blue":
                    print("Hint: The correct wire is the color of the pill Neo took.")
                else:
                    print("Hint: The correct wire is the color of nature and the Matrix code.")
                continue
            
            if user_wire == correct_wire:
                print(f"You cut the {user_wire} wire... and the security system is disabled!")
                break
            else:
                print("Wrong wire! The system resets. Try again!")
                return
        
        print("Security system bypassed! Moving to the next challenge...")
        sleep(2)
              
        #Second challenge: Guess the Word
        print("\nChallenge 2: Guess the Word")
        print("A scrambled code appears on the screen. It contains a hidden word you must decode.")
        word_letters = list("MATRIX")
        random.shuffle(word_letters) #will random shuffle the letters
        scrambled_word = ''.join(word_letters) #prints eventually the scrambled_word
        print(f"The scrambled word is: {scrambled_word}")
        
        while True:
            user_guess = input("Enter the correct word (Type 'hint' for help): ").upper()
            if user_guess == "HINT":
                print("Hint: The word is the name of the simulation you are trapped in.")
                continue
            if user_guess == "MATRIX":
                print("Correct! You have deciphered the hidden word.")
                break
            else:
                print("Incorrect! Try again.")
        
        print("You correctly guessed the word! Moving to the next challenge...")
        sleep(2)
      
    
    #Third challenge: Logic puzzle with fight interaction
    def fight_interaction(self):
        print("\n After you navigated through the maze you want to continue to your last challenge but all of a sudden the door behind you bursts open!")
        sleep(2)
        print("An Agent storms in, eyes locked onto you.")
        sleep(2)
        print("'You thought you could outsmart the system? You're coming with me.'")
        sleep(2)
        print("Trinity yells, 'You have to fight him off while I finish the hack!'")
        sleep(3)

        #The user needs  to choose a weapon
        print("You must act fast so you prepare for a battle! Choose your weapon:")
        print("1. A metal pipe")
        print("2. Your fists")
        print("3. A nearby keyboard")
        weapon = input("Choose your weapon (1/2/3): ")

        #The user's choice outcome
        if weapon == "1":
            print("You swing the metal pipe and hit your opponent on the head, knocking them unconscious!")
        elif weapon == "2":
            print("You engage in hand-to-hand combat and manage to land a strong punch, knocking them out!")
        elif weapon == "3":
            print("You grab the keyboard and smash it over their head, putting them unconscious!")
        else:
            print("You hesitated for too long, and the intruder overpowers you. The system resets!")
            exit()

        print("With your opponent down, you quickly return to hacking the system!")
        sleep(3) #Three seconds break

        #Transition to the next challenge
        print("\nWith the intruder knocked out, you quickly have to move on to the next challenge.")
        sleep(2)

        print("You see a panel with three switches labeled A, B and C")
        sleep(2)
        print("Only one correct combination will disable the final firewall and allow you to finish hacking the system.")
        correct_combination = random.choice(["A", "B", "C"])
        while True:
            switch_choice = input("Which switch do you activate? (A/B/C): ").upper()
            if switch_choice == correct_combination:
                print("The system unlocks! You've successfully hacked The Matrix!")
                self.points += 50
                break
            else:
                print("Incorrect switch! The system resets. Try again!")


    # --------------- Third world: ---------------
                    
    def third_world(self):
        if self.third_portal_piece in self.portalpieces:
            user_input = ""
            answers = ["y", "n"]
            while user_input not in answers:
                user_input = input("You've completed this world already. Starting again will require earning the portal piece again. Continue? (y/n)")
                if user_input == "y":
                    self.portalpieces.remove(self.third_portal_piece)
                elif user_input == "n":
                    self.portalscene()
                else:
                    print("Enter a valid option.")

        self.points = 0
        print("You awaken from cryosleep aboard the Nostromo, the ship eerily silent.")
        sleep(2)
        print("A distress signal led the crew to an unknown planet. Something came back with them...")
        sleep(2)
        print("Your mission: Survive. The ship's AI, Mother, has locked down sections due to an unidentified lifeform.")
        sleep(2)
        print("Ripley stares at the security monitor. 'Something is moving in the ventilation system.'")
        print("Indiana Jones: 'Great. A temple full of snakes would’ve been better.'")
        print("Dallas: 'We need to act fast before this thing finds us.'")
        print("Parker: 'And how the hell do we stop it?'")
        sleep(2)
        print("Indiana Jones: 'Well, this is one hell of a tomb we've stumbled into. Anyone got a plan?'")

        print("\nFirst Dilemma: How do you begin your survival plan?")
        print("1. Investigate the ship's bridge for information")
        print("2. Gather weapons and supplies in the storage bay")
        print("3. Attempt to override Mother's lockdown and regain control")
        print("4. Set up a defensive perimeter and lay traps with Indiana Jones")

        first_choice = input("Choose an option (1-4): ")

        if first_choice == "1":
            self.bridge_investigation()
        elif first_choice == "2":
            self.supply_search()
        elif first_choice == "3":
            self.systems_override()
        elif first_choice == "4":
            self.trap_setup()
        else:
            print("Invalid choice. Restarting decision.")
            self.third_world()

    def bridge_investigation(self):
        print("You access the ship's logs and find an emergency distress call.")
        print("'Last transmission: Crew status unknown. Emergency lockdown engaged.' The message was sent hours ago—but never finished.")
        sleep(2)
        print("What do you do next?")
        print("1. Attempt to send a distress signal to any nearby ships")
        print("2. Share the coordinates with Ripley and plan an escape route")
        choice = input("Choose an option: ")
        if choice == "1":
            print("You send the distress call, but Mother warns that the signal might attract the Xenomorph as well.")
            self.points += 20
            self.signal_consequences()
        elif choice == "2":
            print("Ripley analyzes the coordinates and suggests a stealthy approach to the shuttle.")
            self.points += 30
            self.shuttle_plan()

    def supply_search(self):
        print("You gather weapons and supplies, finding a flamethrower, medkits, and an electric prod.")
        sleep(2)
        print("Do you:")
        print("1. Distribute weapons among the crew")
        print("2. Keep them for yourself and plan a solo escape")
        choice = input("Choose an option: ")
        if choice == "1":
            print("Your crew is now armed and ready to defend themselves.")
            self.items.append(self.flamethrower)
            self.crew_is_armed = True  # New attribute to track the armed crew
            self.points += 30
            self.crew_defense()
        elif choice == "2":
            print("You hoard the weapons, making your survival more likely but straining relationships with the crew.")
            self.items.append(self.flamethrower)
            self.points += 20
            self.solo_escape()

    def crew_defense(self):
        print("With weapons in hand, the crew stands ready.")
        sleep(2)
        print("Ripley: 'Alright, at least now we can fight back.'")
        sleep(2)
        print("Parker: 'Let's take this thing down before it gets us first.'")
        sleep(2)
        print("Do you want to:")
        print("1. Organize a search-and-destroy plan to hunt the Xenomorph down?")
        print("2. Defend a fortified position and wait for an escape opportunity?")
        
        choice = input("Choose an option: ")
        if choice == "1":
            print("You and the crew track the Xenomorph using motion sensors, preparing an ambush.")
            sleep(2)
            print("The plan is risky but might eliminate the threat entirely.")
            self.points += 40
            self.final_battle()
        elif choice == "2":
            print("You hold position in the safest part of the ship, waiting for a chance to escape.")
            sleep(2)
            print("This gives you time to call for help or plan a stealthy escape.")
            self.points += 30
            self.signal_consequences()

    def systems_override(self):
        print("You and Ripley attempt to regain control of the ship. Mother resists your access.")
        sleep(2)
        print("Do you:")
        print("1. Try to hack into the AI directly")
        print("2. Shut down the ship's power to force a reboot")
        choice = input("Choose an option: ")
        if choice == "1":
            print("You successfully gain limited access, unlocking key security doors.")
            self.points += 25
            self.security_breach()
        elif choice == "2":
            print("Powering down the ship causes temporary chaos but allows manual control to be restored.")
            self.points += 35
            self.power_reboot()

    def trap_setup(self):
        print("You and Indiana Jones prepare traps to lure the Xenomorph into an ambush.")
        sleep(2)
        print("Do you:")
        print("1. Set an electric trap using ship batteries")
        print("2. Lure it into the airlock with bait")
        choice = input("Choose an option: ")
        if choice == "1":
            print("The trap is set, but there's only one shot to electrocute the creature.")
            self.points += 25
            self.electric_trap()
        elif choice == "2":
            print("You set up bait and prepare to eject the Xenomorph into space.")
            self.points += 25
            self.airlock_trap()

    def final_battle(self):
        print("You set up an ambush, using the ship’s corridors to funnel the Xenomorph into a trap.")
        sleep(2)
        print("As soon as it appears, the crew opens fire. The creature shrieks in rage.")
        sleep(2)
        
        if self.flamethrower in self.items:
            print("You step forward and unleash a blast of fire, driving the Xenomorph back!")
            sleep(2)
            print("The flames engulf the creature, and as it screeches, Parker fires a final shot.")
            sleep(2)
            print("The Xenomorph collapses, defeated. The nightmare is over.")
            self.points += 50
            self.check_survival()
        else:
            print("The battle is fierce. The Xenomorph kills one of your crew before you manage to injure it.")
            sleep(2)
            print("Ripley: 'We need to end this now!'")
            sleep(2)
            print("You barely manage to trap the creature, ejecting it into space, but at a cost.")
            self.points += 40
            self.check_survival()

    def airlock_trap(self):
        print("With Indiana Jones, you lure the Xenomorph into the airlock using noise and motion.")
        sleep(2)
        print("As soon as it enters, you trigger the airlock sequence, but something goes wrong!")
        sleep(2)
        print("The doors are jammed, and the Xenomorph starts thrashing violently, realizing the trap.")
        print("Jones swings his whip, tangling its legs briefly, buying you enough time to manually override the controls.")
        sleep(2)
        print("The Xenomorph slams against the door, but with one final push, you hit the emergency release.")
        sleep(2)
        print("However, the airlock’s power system is failing! You have a choice:")
        print("1. Try to manually force the doors open, but risk being pulled into space.")
        print("2. Override the system and hope the Xenomorph doesn't recover first.")
        choice = input("Choose an option: ")
    
        if choice == "1":
            print("You and Jones struggle to force the doors open, barely managing before the Xenomorph can react.")
            print("With a final kick, the alien is sucked into space, and you grab onto a safety railing just in time.")
            self.points += 40
            self.check_survival()
        else:
            print("You fumble with the override, but it's too late!")
            print("The Xenomorph lunges at you, claws ripping through your suit. You gasp as the world fades to black...")
            print("\nGame Over, retry this world.")
            self.third_world()

    def power_reboot(self):
        print("You shut down the ship's power, plunging everything into darkness. Emergency lights flicker on, but Mother is now offline.")
        sleep(2)
        print("As the ship reboots, security doors unlock and ventilation systems restart. However, the Xenomorph has been freed from its previous containment area.")
        sleep(2)
        print("You must now move quickly to take advantage of your access before the creature finds you.")
        self.points += 35
        self.check_survival()

    def electric_trap(self):
        print("You and Indiana Jones rig a powerful electric trap using ship batteries and metal plating.")
        sleep(2)
        print("When the Xenomorph appears, you trigger the trap. Sparks fly as the creature convulses, stunned but still alive.")
        sleep(2)
        print("You have only a moment to finish the job before it recovers. Ripley urges action.")
        self.points += 25
        self.check_survival()

    def shuttle_plan(self):
        print("With Ripley, you analyze the coordinates and determine the best route to the shuttle bay.")
        sleep(2)
        print("You must navigate through maintenance tunnels, avoiding security alerts that might draw the Xenomorph.")
        sleep(2)

        if random.choice([True, False]):
            print("The Xenomorph suddenly appears, blocking your path!")
            sleep(2)
            print("You must decide quickly:")

            if self.flamethrower in self.items:
                print("1. Use your flamethrower to force it back.") if self.flamethrower in self.items else None
                print("2. Try to outrun it.")

            choice = input("Choose an option: ")
            if choice == "1" and self.has_flamethrower:
                print("You burn the creature, but your fuel is running low. You reach the shuttle in time.")
                self.points += 30
            elif choice == "2":
                print("You run as fast as you can, barely making it. The Xenomorph almost gets you.")
                self.points += 25
            else:
                print("Without a weapon, you have no choice but to run!")
                self.points += 25
        else:
            print("You make it to the shuttle bay safely, but the Xenomorph isn't far behind.")
            self.points += 30

        print("Now you must seal the bay doors.")
        print("1. Override the controls manually")
        print("2. Blast the doors using an explosive charge")
        
        choice = input("Choose an option: ")
        if choice == "1":
            print("You quickly override the controls, but it's a close call. The doors seal just as the creature lunges.")
            self.points += 30
        elif choice == "2":
            print("You rig an explosive charge, but it damages the shuttle systems. You escape, but navigation is compromised.")
            self.points += 25
            self.check_survival()
        
    def solo_escape(self):
        print("You decide to prioritize your own survival, slipping away while the others remain focused on fortifying the ship.")
        sleep(2)
        print("You make it to an escape pod, but without backup, getting past the Xenomorph proves more difficult than anticipated.")
        sleep(2)
        print("Your decisions have consequences, and your escape will be anything but easy.")
        sleep(2)
        print("Do you:")
        print("1. Try to sneak past the Xenomorph unseen")
        print("2. Use a distraction to lure it away")
        choice = input("Choose an option: ")
        if choice == "1":
            print("You attempt to sneak past, but the creature notices you at the last moment.")
            print("You barely escape in the pod, but not without injury. You drift into space, destination unknown.")
            self.points += 25
        elif choice == "2":
            print("You create a loud distraction, drawing the Xenomorph away long enough to launch the escape pod.")
            print("You watch from the window as the Nostromo disappears behind you. You’re alone in deep space.")
            self.points += 25
            self.check_survival()
    
    def signal_consequences(self):
        print("The distress call is sent, but Mother warns of an unidentified object approaching the ship. Could be help, or something worse.")
        sleep(2)
        print("Ripley suggests monitoring the signal closely, while Indiana Jones insists on preparing for the worst.")
        sleep(2)
        print("Minutes feel like hours. Then, a message crackles through the radio: 'This is the Weyland-Yutani rescue team, responding to distress call. Prepare for extraction.'")
        sleep(2)
        print("But there's a problem. The Xenomorph has detected the signal and is now heading for the docking bay!")
        print("1. Rush to the docking bay and board quickly before it arrives.")
        print("2. Try to lure the Xenomorph away, giving the rescue team time to land.")
        choice = input("Choose an option: ")
    
        if choice == "1":
            print("You and the crew make a desperate sprint for the docking bay.")
            print("Just as you reach the ship, the Xenomorph appears, screeching in fury!")
            if self.points >= 100:
                print("The rescue team opens fire, forcing the creature back long enough for you to board.")
                print("The ship blasts off, escaping just in time. The Nostromo is lost, but you have survived.")
                self.check_survival
            else:
                print("The creature is too fast! It slaughters the crew before you can escape.")
                print("The last thing you see is its fangs closing in on you...")
                print("\nGame Over, retry this world.")
                self.third_world()
        else:
            print("You try to lure the Xenomorph away, using sound and movement to mislead it.")
            print("It works, but at great risk. The creature chases you instead!")
            if self.flamethrower in self.items:
                print("You use the flamethrower to push it back, barely escaping to the ship in time.")
                self.points += 20
                self.check_survival()
            else:
                print("Without a weapon, you are cornered. The Xenomorph strikes, and everything goes black.")
                print("\nGame Over, Retry this world.")
                self.third_world()

    def check_survival(self):
        if self.points < 100:
            print("Somewhere you made a mistake and as you think you are safe you hear sounds behind you, the xenomorph is still there.")
            print("You try to fight, but it's too strong. The last thing you see is its teeth before everything goes dark.")
            print("Game Over. You must restart from the beginning.")
            sleep(2)
            self.third_world()
        else:
            print("Somehow you are alive, as you look at Indiana")
            sleep(2)
            print("Indiana Jones: 'Time to wrap this up. No pun intended to my whip ofcourse.'")
            sleep(2)
            print("You have managed to survive this horror, as you sigh in relief you look on the ground as the portal piece suddenly appears")
            self.portalpieces.append(self.third_portal_piece)
            print(f"Congratulations! You've earned a portal piece. Portal pieces collected: {self.portalpieces}.")
            self.portalscene()

    
    # --------------- Fourth world: Jumanji ---------------
    
    def fourth_world(self):
        # If the user has already achieved the fourth portal piece
        if self.fourth_portal_piece in self.portalpieces:
            # Pre-define user variable
            user_input = ""
            # List of answers
            answers = ["y", "n"]
            # Loop until the user enters one of the given options
            while user_input not in answers:
                # User types answer
                user_input = input("You've already completed this world. If you start again, you'll need to earn this portal piece again. Do you want to continue? (y/n)")
                # If answer is yes
                if user_input == "y":
                    # Remove the fourth portal piece from the list of portal pieces
                    self.portalpieces.remove(self.fourth_portal_piece)
                # If answer is no
                elif user_input == "n":
                    # User goes back to portal scene
                    self.portalscene()
                # If input of the user isn't contained in the options, user should enter another answer
                else:
                    print("Please enter a valid option.")

        print("Welcome to the Jumanji world! You have been transported into the an exciting game where you have to find balance between risk and reward.")
        print(f"\nHello {self.name}, you are now inside the world of Jumanji! In order to win this game you'll need to earn 15 points.")
        print("Your goal is to return alive with the Jaguar's Eye to the statue before Van Pelt stops you!")
        print("Be very cautious! You only have three lives, and every choice shapes your destiny.\n")
    
        # Adventure Points and Lives
        adventure_points = 0
        lives = 3
        required_points = 15  # Adjusted to match the new balancing
    
        # First Decision: Avatar Abilities
        print("Choose your special skill:")
        print("1. Strength and Speed (Dr. Smolder Bravestone)")
        print("2. Stealth and Agility (Ruby Roundhouse)")
        print("3. Zoology and Weapons (Mouse Finbar)")
        print("4. Cartography and Knowledge (Professor Oberon)")
    
        while True:
            try:
                choice = int(input("Enter the number of your chosen skill (1-4): "))
                if choice in [1, 2, 3, 4]:
                    break
                print("Invalid choice! Please enter a number between 1 and 4.")
            except ValueError:
                print("Invalid input! Please enter a valid number.")
    
        print("\nYou find yourself in the jungle, greeted by Nigel, an NPC who gives you a brief on your quest.")
        print("Nigel hands you the Jaguar's Eye, warning you that Van Pelt is hunting you.")
    
        # First Challenge: Path Selection
        print("\nYou arrive at a fork in the path. What will you do?")
        print("1. Venture into the dark jungle")  # cost a life but rewarding
        print("2. Walk along the riverbank")  # safer but lower points
        print("3. Climb up the tall trees to scout the area")  # safer but lower points
    
        while True:
            try:
                choice = int(input("Enter the number (1-3): "))
                if choice == 1:
                    adventure_points += 7
                    lives -= 1
                elif choice == 2:
                    adventure_points += 4
                elif choice == 3:
                    adventure_points += 3
                else:
                    print("Invalid choice! Please enter a number between 1 and 3.")
                    continue
                break
            except ValueError:
                print("Invalid input! Please enter a valid number.")

        print("You had your first major challenge accomplished! Keep up the good work!")
    
        # Second Decision: River or Cave
        print("\nYou reach a wide river with strong rapids and see a dark cave nearby. Do you:")
        print("1. Brave the rapids using an old raft.")  # cost a life but rewarding
        print("2. Enter the cave and find another route.")  # safer but lower points
        print("3. Look for an old bridge crossing.")  # safer but lower points
    
        while True:
            try:
                choice = int(input("Enter 1, 2, or 3: "))
                if choice == 1:
                    adventure_points += 6
                    lives -= 1
                elif choice == 2:
                    adventure_points += 3
                elif choice == 3:
                    adventure_points += 2
                else:
                    print("Invalid choice! Please enter 1, 2, or 3.")
                    continue
                break
            except ValueError:
                print("Invalid input! Please enter a valid number.")

        # Third Decision: The Ruins Puzzle
        print("\nYou stumble upon the ruins of an ancient temple. To proceed, you must find the right way through.")
        print("1. Solve an ancient puzzle carved into the stone.")  # safer but lower points
        print("2. Try to force open a hidden door with brute strength.")  # costs a life but rewarding
        print("3. Search for a secret passage in the overgrown vines.")  # safer but lower points

        while True:
            try:
                choice = int(input("Enter 1, 2, or 3: "))
                if choice == 1:
                    adventure_points += 2
                elif choice == 2:
                    adventure_points += 5
                    lives -= 1
                elif choice == 3:
                    adventure_points += 3
                else:
                    print("Invalid choice! Please enter 1, 2, or 3.")
                    continue
                break
            except ValueError:
                print("Invalid input! Please enter a valid number.")

        # Fourth decision: Reaching the Jaguar Statue
        print("\nAt last, you reach the Jaguar Statue, but Van Pelt and his men guard it fiercely!")
        print("How will you proceed?")
        print("1. Create a diversion using a thrown rock.")  # cost a life but rewarding
        print("2. Stealthily maneuver around and place the jewel unnoticed.")  # safer but lower points
    
        while True:
            try:
                choice = int(input("Enter 1 or 2: "))
                if choice == 1:
                    adventure_points += 4
                    lives -= 1
                elif choice == 2:
                    adventure_points += 2
                else:
                    print("Invalid choice! Please enter 1 or 2.")
                    continue
                break
            except ValueError:
                print("Invalid input! Please enter a valid number.")
    
        # Conclusion
        print(f"\nYou're finished, {self.name}! Let's see the results!")
        print(f"Your final adventure score: {adventure_points} points.")
        print(f"Lives remaining: {lives}")
    
        if adventure_points >= required_points and lives > 0:
            print("You made it out alive and returned to reality! Well done! You took risks when necessary and remained cautious when needed!")
            # User earns portal piece of this world
            self.portalpieces.append(self.fourth_portal_piece)
            print("You've won the portal piece of this world. Congrats!")
        else:
            print("You have not met the required points or ran out of lives... You remain trapped in Jumanji! Tip: find a better balance between risk and reward, choose another avatar to get other strenghts.")
            # Goes back to beginning of this world
            self.fourth_world()
        while True:
            restart_game = input("Would you like to try again? (yes/no): ").strip().lower()
            if restart_game == "yes":
                # Go back to the beginning of this world
                self.fourth_world()
                break
            elif restart_game == "no":
                print("Thanks for playing! See you next time.")
                # Go back to portal scene
                self.portalscene()
                break
            else:
                print("Invalid input! Please enter 'yes' or 'no'.")

    # --------------- Start game function ---------------
    def start_game(self):
        while not self.game_over:
            pass

# --------------- Start game ---------------
# Start the game (Player has 0 points when starting the game)
if __name__ == "__main__":
    game = movieportal_game(name="Player", points=0)
    game.start_game()
# Out:
# Indiana Jones: 'Welcome traveller, my name is Indiana Jones.'
# Indiana Jones: 'What is your name?' d
# Nice to meet you d!
# Indiana Jones: 'The craziest thing has happened to me.'
# Indiana Jones: 'I was running towards the temple of doom and all of a sudden a portal appeared in my pathway.'
# Indiana Jones: 'I got sucked into this portal and now I'm stuck here...'
# Indiana Jones: 'It seems like another dimension. Could you help me find my way back to the temple of doom?' (y/n) y
# Thank you for wanting to help me. Let's start this adventure!
# A bright blue portal swirls in front of you...
# You step closer, feeling a strange pull.
#
# You feel light as air and open your eyes. There is no ground beneath you, yet you are standing. It seems like you are somewhere in space. The space is filled with all kinds of colours swirling around you. It is absolutely beautiful.
# While you are taking the space in with eyes full of wonder, Indiana Jones clears his throat.
# ...
